# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/kaggle/input/bank-customers-prediction/bank.csv",sep=";")

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df["loan"].value_counts()
# Out:
# loan
# no         33950
# yes         6248
# unknown      990
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="loan",data=df,palette="Set1")
plt.show()

# %%
df["contact"].value_counts()
# Out:
# contact
# cellular     26144
# telephone    15044
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="contact",data=df,palette="hsv")
plt.show()

# %%
df["month"].value_counts()
# Out:
# month
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="month",data=df,palette="cool")
plt.show()

# %%
df["job"].value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
job_counts = df["job"].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(job_counts, labels=job_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Job Categories')
plt.axis("equal")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(y="job",data=df,palette="Set2")
plt.show()

# %%
df["marital"].value_counts()
# Out:
# marital
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64

# %%
marital_counts = df["marital"].value_counts()

plt.figure(figsize=(12,10))

plt.pie(marital_counts, labels=marital_counts.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.4))
plt.title('Distribution of Marital Status')

centre_circle = plt.Circle((0,0),0.2,color='white', fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.show()

# %%
df["education"].value_counts()
# Out:
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(y="education",data=df,palette="winter")
plt.show()

# %%
df["default"].value_counts()
# Out:
# default
# no         32588
# unknown     8597
# yes            3
# Name: count, dtype: int64

# %%
default_counts = df["default"].value_counts()

plt.figure(figsize=(10,8))
plt.pie(default_counts, labels=default_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Default Status')
plt.axis("equal")
plt.show()

# %%
df["housing"].value_counts()
# Out:
# housing
# yes        21576
# no         18622
# unknown      990
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="housing",data=df,palette="summer")
plt.show()

# %%
df["day_of_week"].value_counts()
# Out:
# day_of_week
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="day_of_week",data=df,palette="spring")
plt.show()

# %%
df.drop(columns=["default"],axis=1,inplace=True)

# %%
df["poutcome"].value_counts()
# Out:
# poutcome
# nonexistent    35563
# failure         4252
# success         1373
# Name: count, dtype: int64

# %%
poutcome_counts = df["poutcome"].value_counts()
color=["red","blue","navy"]
plt.figure(figsize=(10,8))
plt.pie(poutcome_counts, labels=poutcome_counts.index, autopct='%1.1f%%', startangle=140,colors=color)
plt.title('Distribution of Previous Outcome')
plt.axis("equal")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x="age", kde=True,hue="loan")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x="duration", kde=True,hue="housing",bins=50)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x="pdays", kde=True,bins=50)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x="cons.price.idx", kde=True,bins=50,hue="loan")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x="cons.conf.idx", kde=True,bins=50,hue="housing")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x="euribor3m", kde=True,bins=100,hue="month")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x="nr.employed", kde=True,bins=100,hue="contact")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df["y"].value_counts()
# Out:
# y
# no     36548
# yes     4640
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="y",data=df,palette="Wistia")
plt.show()

# %%
df = df[df['job'] != 'unknown']
df = df[df['marital'] != 'unknown']
df = df[df['education'] != 'unknown']
df = df[df['housing'] != 'unknown']

# %%
df["job"]=df["job"].replace({"admin.":0,"blue-collar":1,"technician":2,"services":3,"management":4,
                            "retired":5,"entrepreneur":6,"self-employed":7,"housemaid":8,"unemployed":9,"student":10})
df["marital"]=df["marital"].replace({"married":0,"single":1,"divorced":2})
df["education"]=df["education"].replace({"university.degree":0,"high.school":1,"basic.9y":2,"professional.course":3,"basic.4y":4,"basic.6y":5,"illiterate":6})
df["housing"]=df["housing"].replace({"yes":1,"no":0})
df["loan"]=df["loan"].replace({"yes":1,"no":0})
df["contact"]=df["contact"].replace({"cellular":0,"telephone":1})
df["month"]=df["month"].replace({"may":0,"jul":1,"aug":2,"jun":3,"nov":4,"apr":5,"oct":6,"sep":7,"mar":8,"dec":9})
df["day_of_week"]=df["day_of_week"].replace({"thu":0,"mon":1,"wed":2,"tue":3,"fri":4})
df["y"]=df["y"].replace({"yes":1,"no":0})
df["poutcome"]=df["poutcome"].replace({"nonexistent":0,"failure":1,"success":2})
# Out:
# /tmp/ipykernel_3396/3736655739.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["job"]=df["job"].replace({"admin.":0,"blue-collar":1,"technician":2,"services":3,"management":4,
# /tmp/ipykernel_3396/3736655739.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["marital"]=df["marital"].replace({"married":0,"single":1,"divorced":2})
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
col=["age","duration","pdays","cons.price.idx","cons.conf.idx","euribor3m","nr.employed"]
scaler = MinMaxScaler()
df[col]=scaler.fit_transform(df[col])

# %%
X=df.drop(columns="y",axis=1)
Y=df["y"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print("Training set shapes - X: {}, y: {}".format(X_train.shape, y_train.shape))
print("Testing set shapes - X: {}, y: {}".format(X_test.shape, y_test.shape))
# Out:
# Training set shapes - X: (30596, 19), y: (30596,)
# Testing set shapes - X: (7649, 19), y: (7649,)

# %%
param_dist = {
    'n_estimators': randint(50, 200),
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': randint(3, 10)
}
gb=GradientBoostingClassifier()
random_search = RandomizedSearchCV(gb, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)

random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#                    param_distributions={'learning_rate': [0.1, 0.01, 0.001],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7d09c1b0ead0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7d09c848bd30>},
#                    random_state=42)

# %%
best_params = random_search.best_params_
best_score = random_search.best_score_

print("Best Parameters:", best_params)
print("==================================================")
print("Best Score:", best_score)
# Out:
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 107}
# ...
# Best Score: 0.9154138027167068

# %%
best_gb=GradientBoostingClassifier(learning_rate=0.1, max_depth=6, n_estimators=107)
best_gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(max_depth=6, n_estimators=107)

# %%
feat_importances = pd.Series(best_gb.feature_importances_, index = X.columns)
feat_importances.nlargest(len(df.columns)).plot(kind = 'barh',color="indigo",figsize=(10,8))

plt.xlabel('Feature Importances')
plt.ylabel('Features Name')
plt.show()

# %%
feat_importances.sort_values(ascending =True)
# Out:
# loan              0.002634
# emp.var.rate      0.002830
# housing           0.003015
# marital           0.004179
# contact           0.005470
# previous          0.006504
# cons.conf.idx     0.009932
# job               0.012309
# education         0.012726
# cons.price.idx    0.013561
# poutcome          0.013944
# day_of_week       0.015082
# campaign          0.017216
# pdays             0.028895
# month             0.042779
# age               0.044296
# euribor3m         0.074407
# nr.employed       0.253447
# duration          0.436772
# dtype: float64

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
pred=best_gb.predict(X_test)
accuracy = accuracy_score(y_test,pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9160674597986664

# %%
cf=confusion_matrix(y_test,pred)
label_name=["No","Yes"]
plt.figure(figsize=(10, 8))
sns.heatmap(cf, annot=True, fmt="d", cmap="PRGn", xticklabels=label_name, yticklabels=label_name)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, pred,target_names=label_name))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.94      0.96      0.95      6792
#          Yes       0.65      0.54      0.59       857
#
#     accuracy                           0.92      7649
#    macro avg       0.80      0.75      0.77      7649
# weighted avg       0.91      0.92      0.91      7649

# %%
from sklearn.metrics import roc_curve, roc_auc_score


y_probs = best_gb.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
plt.figure(figsize=(10,8))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc_score(y_test, y_probs))
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, auc

precision, recall, _ = precision_recall_curve(y_test, y_probs)
pr_auc = auc(recall, precision)
plt.figure(figsize=(10,8))
plt.plot(recall, precision, color='blue', lw=2, label=f'Precision-Recall Curve (AUC = {pr_auc:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.legend(loc="lower left")
plt.grid(True)
plt.show()
